# %% [markdown]
# # Sección 2 — ¿Qué distingue a un asteroide potencialmente peligroso?
# **Responsable:** Alumno 2
#
# **Entrada:** `data/processed/asteroids_clean.parquet`
#
# ---
# **Preguntas a responder:**
# - ¿Difieren significativamente el MOID, el tamaño o la velocidad entre grupos?
# - ¿Hay asociación estadística entre clase orbital y peligrosidad?
