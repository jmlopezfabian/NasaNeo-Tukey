# %% [markdown]
# # Sección 4 — Modelo multivariado del riesgo orbital (MOID)
# **Responsable:** Alumno 4
#
# **Entrada:** `data/processed/asteroids_clean.parquet`
#
# ---
# **Preguntas a responder:**
# - ¿Qué características orbitales explican la distancia mínima de cruce?
# - ¿El modelo es estable entre folds?
# - ¿Cumple los supuestos de OLS?
