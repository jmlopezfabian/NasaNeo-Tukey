# %% [markdown]
# # Sección 6 — Historia observacional y sesgo de descubrimiento
# **Responsable:** Alumno 6
#
# **Entrada:** `data/processed/asteroids_clean.parquet`
#
# ---
# **Preguntas a responder:**
# - ¿Cómo ha evolucionado el ritmo de descubrimiento de NEOs por década?
# - ¿Difiere significativamente el tamaño promedio según la época de descubrimiento (sesgo de selección)?
# - ¿Están mejor caracterizados los asteroides descubiertos hace más tiempo?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent))

from src.data_loader import cargar_asteroides

df = cargar_asteroides()
df.shape

# %% [markdown]
# ## 1. Construcción de columnas derivadas
#
# Crear `decada_descubrimiento` a partir de `first_observation_date` y `arco_anios` a partir de `data_arc_days`.

# %%
# TODO: derivar decada_descubrimiento y arco_anios

# %% [markdown]
# ## 2. Serie de tiempo: descubrimientos por década
#
# **Gráfica:** barras o línea del número de asteroides descubiertos por década.

# %%
# TODO: conteo por década y gráfica

# %% [markdown]
# ## 3. Sesgo de selección: diámetro y observaciones por época
#
# **Gráficas:** boxplots de `diameter_min_m` y de `observations_used` agrupados por `decada_descubrimiento`.

# %%
# TODO: boxplots de diámetro y observaciones por década

# %% [markdown]
# ## 4. Arco observacional promedio por época
#
# **Gráfica:** barras del arco observacional promedio (`arco_anios`) por `decada_descubrimiento`.

# %%
# TODO: barras del arco observacional promedio por década

# %% [markdown]
# ## 5. Prueba ANOVA: ¿difiere el diámetro promedio entre décadas?
#
# H₀: el diámetro medio es igual en todas las décadas.
# H₁: al menos una década difiere significativamente.

# %%
# TODO: scipy.stats.f_oneway con los grupos de cada década
# Reportar estadístico F y p-valor

# %% [markdown]
# ## 6. Conclusiones
#
# - Ritmo de descubrimiento: …
# - Sesgo de selección (evidencia estadística): …
# - Calidad del seguimiento por época: …
