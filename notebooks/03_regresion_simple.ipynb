# %% [markdown]
# # Sección 3 — Predicción del tamaño a partir del brillo
# **Responsable:** Alumno 3
#
# **Entrada:** `data/processed/asteroids_clean.parquet`
#
# ---
# **Preguntas a responder:**
# - ¿Se puede predecir el diámetro de un asteroide a partir de su magnitud?
# - ¿Qué tan bien ajusta el modelo?
# - ¿Cómo cambia la convergencia del gradiente con y sin escalado?
