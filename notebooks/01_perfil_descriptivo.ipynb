# %% [markdown]
# # Sección 1 — Perfil descriptivo y estructura del catálogo de NEOs
# **Responsable:** Alumno 1
#
# **Entrada:** `data/processed/asteroids_clean.parquet`
#
# ---
# **Preguntas a responder:**
# - ¿Cómo se distribuyen el diámetro y la magnitud, y cuáles son los asteroides atípicos?
# - ¿Qué variables numéricas están correlacionadas entre sí?
# - ¿Difiere el perfil orbital típico entre clases APO/AMO/ATE?
